# %% [markdown]
# # Predicting Language Program from Economic Index

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from   sklearn.linear_model import LogisticRegression
from   sklearn.model_selection import cross_val_score

# %%
full_data = pd.read_csv("full_data.csv")
full_data = full_data.loc[(full_data["Language"] == "Spanish") | (full_data["Language"] == "Chinese") | (full_data["Language"] == "French")]

# %%
display(full_data)
# Out:
#        Borough Borough/Citywide Office (B/CO)  District     DBN  \
# 0    Manhattan                      Manhattan         1  01M020
# 1    Manhattan                      Manhattan         1  01M378
# 2     Brooklyn                 Brooklyn North        14  14K250
# 3       Queens                   Queens North        24  24Q013
# 4    Manhattan                      Manhattan         1  01M020
# ..         ...                            ...       ...     ...
# 257  Manhattan                      Manhattan         3  03M256
# 258   Brooklyn                 Brooklyn North        13  13K003
# 259   Brooklyn                 Brooklyn North        13  13K020
# 260   Brooklyn                 Brooklyn North        13  13K691
# 261   Brooklyn                 Brooklyn North        16  16K005
#
#                        school_name_x                  School Category  \
# 0               P.S. 020 Anna Silver                       Elementary
# 1          School for Global Leaders  Junior High-Intermediate-Middle
# 2         P.S. 250 George H. Lindsay                       Elementary
# 3          P.S. 013 Clement C. Moore                       Elementary
# 4               P.S. 020 Anna Silver                       Elementary
# ..                               ...                              ...
# 257                Lafayette Academy  Junior High-Intermediate-Middle
# 258     P.S. 003 The Bedford Village                       Elementary
# 259            P.S. 020 Clinton Hill                       Elementary
# 260  Fort Greene Preparatory Academy  Junior High-Intermediate-Middle
# 261       P.S. 005 Dr. Ronald McNair                       Elementary
#
#            Program Language General/Special Education  \
# 0    Dual Language  Chinese         General Education
# 1    Dual Language  Chinese         General Education
# 2    Dual Language  Chinese         General Education
# 3    Dual Language  Chinese         General Education
# 4    Dual Language  Spanish         General Education
# ..             ...      ...                       ...
# 257  Dual Language   French         General Education
# 258  Dual Language   French         General Education
# 259  Dual Language   French         General Education
# 260  Dual Language   French         General Education
# 261  Dual Language   French         General Education
#
#                        school_name_y  ... % Students with Disabilities  \
# 0               P.S. 020 Anna Silver  ...                        0.220
# 1          School for Global Leaders  ...                        0.407
# 2         P.S. 250 George H. Lindsay  ...                        0.167
# 3          P.S. 013 Clement C. Moore  ...                        0.147
# 4               P.S. 020 Anna Silver  ...                        0.220
# ..                               ...  ...                          ...
# 257                Lafayette Academy  ...                        0.224
# 258     P.S. 003 The Bedford Village  ...                        0.195
# 259            P.S. 020 Clinton Hill  ...                        0.158
# 260  Fort Greene Preparatory Academy  ...                        0.316
# 261       P.S. 005 Dr. Ronald McNair  ...                        0.258
#
#      # English Language Learners  % English Language Learners  # Poverty  \
# 0                             61                        0.131        352
# 1                             17                        0.083        172
# 2                             44                        0.108        330
# 3                            385                        0.277       1065
# 4                             61                        0.131        352
# ..                           ...                          ...        ...
# 257                           16                        0.112         97
# 258                           21                        0.070        267
# 259                           26                        0.048        288
# 260                           12                        0.057        192
# 261                           13                        0.052        197
#
#      % Poverty  Economic Need Index  mostCommonEthnicGroup  language_number  \
# 0        75.9%                78.2%             % Hispanic                1
# 1        84.3%                84.7%             % Hispanic                1
# 2        81.1%                86.4%             % Hispanic                1
# 3        76.6%                79.4%             % Hispanic                1
# 4        75.9%                78.2%             % Hispanic                9
# ..         ...                  ...                    ...              ...
# 257      67.8%                63.2%                % Black                2
# 258      88.4%                86.6%                % Black                2
# 259      53.4%                48.0%                % Black                2
# 260      91.9%                88.3%                % Black                2
# 261      79.4%                81.6%                % Black                2
#
#      ethnicity_number  predicted_language
# 0                   2             Spanish
# 1                   2             Spanish
# 2                   2             Spanish
# 3                   2             Spanish
# 4                   2             Spanish
# ..                ...                 ...
# 257                 1      Haitian Creole
# 258                 1      Haitian Creole
# 259                 1      Haitian Creole
# 260                 1      Haitian Creole
# 261                 1      Haitian Creole
#
# [251 rows x 51 columns]

# %%
#cleaning the economic need index 

####### drop all schools where the economic need index of rows is above 95%  
# print(full_data[full_data["Economic Need Index"]=="Above 95%"])
full_data.drop([5,13,18,19,50,51,52,56,60,64,69,70,71,88,119,186,187],inplace=True)
print("this is the number of rows " + str(len(full_data)))

#rename economic need index 
full_data = full_data.rename(columns={"Economic Need Index":"economic_need_index"})
# Out:
# this is the number of rows 234

# %%
#remove percent sign
full_data["df_percent"] = full_data["economic_need_index"].str.rstrip('%').astype(float)
full_data.tail()
# Out:
#        Borough Borough/Citywide Office (B/CO)  District     DBN  \
# 257  Manhattan                      Manhattan         3  03M256
# 258   Brooklyn                 Brooklyn North        13  13K003
# 259   Brooklyn                 Brooklyn North        13  13K020
# 260   Brooklyn                 Brooklyn North        13  13K691
# 261   Brooklyn                 Brooklyn North        16  16K005
#
#                        school_name_x                  School Category  \
# 257                Lafayette Academy  Junior High-Intermediate-Middle
# 258     P.S. 003 The Bedford Village                       Elementary
# 259            P.S. 020 Clinton Hill                       Elementary
# 260  Fort Greene Preparatory Academy  Junior High-Intermediate-Middle
# 261       P.S. 005 Dr. Ronald McNair                       Elementary
#
#            Program Language General/Special Education  \
# 257  Dual Language   French         General Education
# 258  Dual Language   French         General Education
# 259  Dual Language   French         General Education
# 260  Dual Language   French         General Education
# 261  Dual Language   French         General Education
#
#                        school_name_y  ... # English Language Learners  \
# 257                Lafayette Academy  ...                          16
# 258     P.S. 003 The Bedford Village  ...                          21
# 259            P.S. 020 Clinton Hill  ...                          26
# 260  Fort Greene Preparatory Academy  ...                          12
# 261       P.S. 005 Dr. Ronald McNair  ...                          13
#
#      % English Language Learners  # Poverty  % Poverty  economic_need_index  \
# 257                        0.112         97      67.8%                63.2%
# 258                        0.070        267      88.4%                86.6%
# 259                        0.048        288      53.4%                48.0%
# 260                        0.057        192      91.9%                88.3%
# 261                        0.052        197      79.4%                81.6%
#
#      mostCommonEthnicGroup  language_number  ethnicity_number  \
# 257                % Black                2                 1
# 258                % Black                2                 1
# 259                % Black                2                 1
# 260                % Black                2                 1
# 261                % Black                2                 1
#
#      predicted_language  df_percent
# 257      Haitian Creole        63.2
# 258      Haitian Creole        86.6
# 259      Haitian Creole        48.0
# 260      Haitian Creole        88.3
# 261      Haitian Creole        81.6
#
# [5 rows x 52 columns]

# %%
economic_model = LogisticRegression(multi_class = 'multinomial', solver = 'newton-cg').fit(full_data[["df_percent"]], full_data["language_number"])
economic_model.score(full_data[["df_percent"]], full_data["language_number"])
# Out:
# 0.8418803418803419

# %% [markdown]
# ### Cross Validation

# %%
scores = cross_val_score(
    LogisticRegression(multi_class = 'multinomial', solver = 'newton-cg'), 
    full_data[["df_percent"]], 
    full_data["Language"], 
    cv=5
)

# print(scores)
print(f'Mean cross-validated accuracy: {scores.mean():.3f}')
# Out:
# Mean cross-validated accuracy: 0.829
